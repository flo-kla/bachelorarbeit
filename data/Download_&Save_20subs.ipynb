# %%
import sqlite3
from sqlite3 import Error
import pandas as pd


def create_connection(db_file):
    """ create a database connection to the SQLite database
        specified by the db_file
    :param db_file: database file
    :return: Connection object or None
    """
    conn = None
    try:
        conn = sqlite3.connect(db_file)
    except Error as e:
        print(e)

    return conn


def select_all_tasks(conn,query):
    """
    Query all rows in the tasks table
    :param conn: the Connection object
    :return:
    """
    cur = conn.cursor()
    cur.execute(query)

    rows = cur.fetchall()
    return rows    

#"SELECT body FROM May2015 WHERE subreddit = 'hockey'"

# %%
database = "C:/Users/flori/Dropbox/Desktop/bachelorarbeit/realshit/Datasets/20subs/database.sqlite"

    # create a database connection
conn = create_connection(database)
with conn:
    df_hockey = pd.DataFrame(select_all_tasks(conn,"SELECT body FROM May2015 WHERE subreddit = 'hockey'"))
    df_politics = pd.DataFrame(select_all_tasks(conn,"SELECT body FROM May2015 WHERE subreddit = 'politics'"))
    df_atheism = pd.DataFrame(select_all_tasks(conn,"SELECT body FROM May2015 WHERE subreddit = 'atheism'"))
    df_baseball = pd.DataFrame(select_all_tasks(conn,"SELECT body FROM May2015 WHERE subreddit = 'baseball'"))
    df_bitcoin = pd.DataFrame(select_all_tasks(conn,"SELECT body FROM May2015 WHERE subreddit = 'Bitcoin'"))
    df_christianity = pd.DataFrame(select_all_tasks(conn,"SELECT body FROM May2015 WHERE subreddit = 'Christianity'"))
    df_cars = pd.DataFrame(select_all_tasks(conn,"SELECT body FROM May2015 WHERE subreddit = 'cars'"))
    df_motorcycles = pd.DataFrame(select_all_tasks(conn,"SELECT body FROM May2015 WHERE subreddit = 'motorcycles'"))
    df_guns = pd.DataFrame(select_all_tasks(conn,"SELECT body FROM May2015 WHERE subreddit = 'guns'"))
    df_space = pd.DataFrame(select_all_tasks(conn,"SELECT body FROM May2015 WHERE subreddit = 'space'"))
    df_debatereligion = pd.DataFrame(select_all_tasks(conn,"SELECT body FROM May2015 WHERE subreddit = 'DebateReligion'"))
    df_worldpolitics = pd.DataFrame(select_all_tasks(conn,"SELECT body FROM May2015 WHERE subreddit = 'worldpolitics'"))
    df_gamesale = pd.DataFrame(select_all_tasks(conn,"SELECT body FROM May2015 WHERE subreddit = 'GameSale'"))
    df_hardware = pd.DataFrame(select_all_tasks(conn,"SELECT body FROM May2015 WHERE subreddit = 'hardware'"))
    df_medicalschool = pd.DataFrame(select_all_tasks(conn,"SELECT body FROM May2015 WHERE subreddit = 'medicalschool'"))
    df_windows10 = pd.DataFrame(select_all_tasks(conn,"SELECT body FROM May2015 WHERE subreddit = 'Windows10'"))
    df_mac = pd.DataFrame(select_all_tasks(conn,"SELECT body FROM May2015 WHERE subreddit = 'mac'"))
    df_graphicdesign = pd.DataFrame(select_all_tasks(conn,"SELECT body FROM May2015 WHERE subreddit = 'graphic_design'"))
    df_askelectronics = pd.DataFrame(select_all_tasks(conn,"SELECT body FROM May2015 WHERE subreddit = 'AskElectronics'"))
    df_windows = pd.DataFrame(select_all_tasks(conn,"SELECT body FROM May2015 WHERE subreddit = 'windows'"))

# %%
df_hockey["label"] = "hockey"
df_politics["label"] = "politics"
df_atheism["label"] = "atheism"
df_baseball["label"] = "baseball"
df_bitcoin["label"] = "Bitcoin"
df_christianity["label"] = "Christianity"
df_cars["label"] = "cars"
df_motorcycles["label"] = "motorcycles"
df_guns["label"] = "guns"
df_space["label"] = "space"
df_debatereligion["label"] = "DebateReligion"
df_worldpolitics["label"] = "worldpolitics"
df_gamesale["label"] = "GameSale"
df_hardware["label"] = "hardware"
df_medicalschool["label"] = "medicalschool"
df_windows10["label"] = "Windows10"
df_mac["label"] = "mac"
df_graphicdesign["label"] ="graphic_design"
df_askelectronics["label"] = "AskElectronics"
df_windows["label"] = "windows"

# %%
df_hockey.to_excel("C:/Users/flori/Dropbox/Desktop/bachelorarbeit/realshit/Datasets/20subs/original/hockey.xlsx")
df_politics.to_excel("C:/Users/flori/Dropbox/Desktop/bachelorarbeit/realshit/Datasets/20subs/original/politics.xlsx")
df_atheism.to_excel("C:/Users/flori/Dropbox/Desktop/bachelorarbeit/realshit/Datasets/20subs/original/atheism.xlsx")
df_baseball.to_excel("C:/Users/flori/Dropbox/Desktop/bachelorarbeit/realshit/Datasets/20subs/original/baseball.xlsx")
df_bitcoin.to_excel("C:/Users/flori/Dropbox/Desktop/bachelorarbeit/realshit/Datasets/20subs/original/bitcoin.xlsx")   
df_christianity.to_excel("C:/Users/flori/Dropbox/Desktop/bachelorarbeit/realshit/Datasets/20subs/original/christianity.xlsx")  
df_cars.to_excel("C:/Users/flori/Dropbox/Desktop/bachelorarbeit/realshit/Datasets/20subs/original/cars.xlsx")    
df_motorcycles.to_excel("C:/Users/flori/Dropbox/Desktop/bachelorarbeit/realshit/Datasets/20subs/original/motorcycles.xlsx") 
df_guns.to_excel("C:/Users/flori/Dropbox/Desktop/bachelorarbeit/realshit/Datasets/20subs/original/guns.xlsx")
                 
df_space.to_excel("C:/Users/flori/Dropbox/Desktop/bachelorarbeit/realshit/Datasets/20subs/original/space.xlsx")
df_debatereligion.to_excel("C:/Users/flori/Dropbox/Desktop/bachelorarbeit/realshit/Datasets/20subs/original/debatereligion.xlsx")     
df_worldpolitics.to_excel("C:/Users/flori/Dropbox/Desktop/bachelorarbeit/realshit/Datasets/20subs/original/worldpolitics.xlsx")
df_gamesale.to_excel("C:/Users/flori/Dropbox/Desktop/bachelorarbeit/realshit/Datasets/20subs/original/gamesale.xlsx")
df_hardware.to_excel("C:/Users/flori/Dropbox/Desktop/bachelorarbeit/realshit/Datasets/20subs/original/hardware.xlsx")
df_medicalschool.to_excel("C:/Users/flori/Dropbox/Desktop/bachelorarbeit/realshit/Datasets/20subs/original/medicalschool.xlsx") 
df_windows10.to_excel("C:/Users/flori/Dropbox/Desktop/bachelorarbeit/realshit/Datasets/20subs/original/windows10.xlsx")
df_mac.to_excel("C:/Users/flori/Dropbox/Desktop/bachelorarbeit/realshit/Datasets/20subs/original/mac.xlsx")  
df_graphicdesign.to_excel("C:/Users/flori/Dropbox/Desktop/bachelorarbeit/realshit/Datasets/20subs/original/graphicdesign.xlsx")
df_askelectronics.to_excel("C:/Users/flori/Dropbox/Desktop/bachelorarbeit/realshit/Datasets/20subs/original/askelectronics.xlsx")
df_windows.to_excel("C:/Users/flori/Dropbox/Desktop/bachelorarbeit/realshit/Datasets/20subs/original/windows.xlsx")
# Out:
# C:\Users\flori\Anaconda3\lib\site-packages\xlsxwriter\worksheet.py:935: UserWarning: Ignoring URL 'http://www.theprojectionproject.com/
#
# &gt;Our%20current%20projection%20methodology%20matches%20your%20searched%20player%20based%20on%20NHLE%20per%20Game%20in%20their%20Draft%20Year.
#
# &gt;Any%20drafted%20player%20who%20scored%20at%20a%20rate%20within%20+/-%204(Updated%20March%2025)%20NHLE%20in%20their%20draft%20year%20will%20be%20considered%20a%20comparable.
#
# &gt;Example:%20If%20you%20searched%20a%20player%20who%20had%20a%20scoring%20rate%20of%2028%20NHLE%20any%20player%20who%20scored%20between%20a%2026-30%20NHLE%20rate%20will%20be%20counted%20in%20your%20comparison.
#
# &gt;This%20benchmark%20provides%20an%20adequate%20sample%20for%20most%20scoring%20levels%20and%20provides%20a%20reasonable%20comparison.%20We%20will%20soon%20be%20adding%20the%20ability%20to%20modify%20what%20scoring%20criteria%20you%20would%20like%20to%20match%20on.
#
# ...

# %%
frames = [df_hockey,df_politics,df_atheism,df_baseball]
data = pd.concat(frames)
data.to_excel("C:/Users/flori/Dropbox/Desktop/bachelorarbeit/realshit/Datasets/20subs/original/full_data_part1.xlsx")

# %%
frames2 = [df_bitcoin,df_christianity,df_cars,df_motorcycles,df_guns,df_space,df_debatereligion,df_worldpolitics,df_gamesale,df_hardware,df_medicalschool,df_windows10,df_mac,df_graphicdesign,df_askelectronics,df_windows]
data2 = pd.concat(frames2)
data2.to_excel("C:/Users/flori/Dropbox/Desktop/bachelorarbeit/realshit/Datasets/20subs/original/full_data_part2.xlsx")
